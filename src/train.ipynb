# %%
import numpy
image = numpy.load("/home/featurize/data/data/train0.npy")
image.shape
# Out:
# (3, 160, 160)

# %%
# %run DDPM/train.py "/home/featurize/data/data/"
# Out:
# Start Training
# 100%|██████████| 200/200 [01:36<00:00,  2.08it/s, loss=0.086]
# Finished epoch 1/200, mean-loss: 0.1571368657425046
# 100%|██████████| 200/200 [01:36<00:00,  2.08it/s, loss=0.0782]
# Finished epoch 2/200, mean-loss: 0.08556342916563153
# 100%|██████████| 200/200 [01:35<00:00,  2.08it/s, loss=0.0561]
# Finished epoch 3/200, mean-loss: 0.07250952990725637
# 100%|██████████| 200/200 [01:35<00:00,  2.09it/s, loss=0.0421]
# Finished epoch 4/200, mean-loss: 0.06438124221749604
# 100%|██████████| 200/200 [01:35<00:00,  2.09it/s, loss=0.0734]
# Finished epoch 5/200, mean-loss: 0.0595991728361696
# 100%|██████████| 200/200 [01:35<00:00,  2.09it/s, loss=0.0592]
# Finished epoch 6/200, mean-loss: 0.0557165462244302
# 100%|██████████| 200/200 [01:36<00:00,  2.08it/s, loss=0.0424]
# Finished epoch 7/200, mean-loss: 0.053722502347081896
# 100%|██████████| 200/200 [01:36<00:00,  2.08it/s, loss=0.0321]
# Finished epoch 8/200, mean-loss: 0.053125061318278315
# ...
